# %%
import numpy as np
import pandas as pd

from sklearn.neighbors import KNeighborsClassifier

data_gam = pd.read_csv("emc_gam.txt")
data_neutron = pd.read_csv("emc_neutron.txt")

def compute_fom(S, B):
    return S / np.sqrt(S + B)

# %% [markdown]
# Now we will normalize all data

# %%
def normalize_data(col, dataset):
    col_data = dataset[col]
    new_col = f"{col}_normal"
    normal = (col_data - col_data.mean()) / col_data.std()

    dataset[new_col] = normal

features = ["Th", "Ph", "E", "NrHits", "NrBumps", "E1", "E1E9", "E9E25", "Z20", "Z53", "LatMom"]
for feat in features:
    normalize_data(feat, data_gam)
    normalize_data(feat, data_neutron)

# Verify that the data is properly normalized.
features_norm = map(lambda s: s + "_normal", features)
data_gam[features_norm].describe()
# Out:
#           Th_normal     Ph_normal      E_normal  NrHits_normal  \
# count  4.336000e+04  4.336000e+04  4.336000e+04   4.336000e+04
# mean   4.752246e-17  3.670700e-17  3.221695e-16  -3.020134e-16
# std    1.000000e+00  1.000000e+00  1.000000e+00   1.000000e+00
# min   -1.714058e+00 -1.726741e+00 -2.438603e+00  -3.180293e+00
# 25%   -8.612775e-01 -8.693356e-01 -8.449423e-01  -6.352730e-01
# 50%   -3.290599e-02  3.063332e-06 -5.537766e-03   4.339917e-02
# 75%    8.359255e-01  8.594248e-01  8.591849e-01   7.220713e-01
# max    1.763398e+00  1.734368e+00  1.976788e+00   4.624436e+00
#
#        NrBumps_normal     E1_normal   E1E9_normal  E9E25_normal    Z20_normal  \
# count    4.336000e+04  4.336000e+04  4.336000e+04  4.336000e+04  4.336000e+04
# mean    -5.047213e-16  2.584239e-16  4.611317e-16 -3.178433e-15  3.777872e-15
# std      1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min     -1.431263e-01 -2.168963e+00 -3.500907e+00 -1.443852e+01 -2.643950e+01
# 25%     -1.431263e-01 -8.164739e-01 -6.841280e-01 -8.737469e-02 -7.551620e-02
# 50%     -1.431263e-01 -9.417515e-02  2.679726e-01  1.426129e-01  1.968071e-01
# 75%     -1.431263e-01  7.474467e-01  7.792199e-01  3.549591e-01  4.182727e-01
# max      3.214593e+01  2.667699e+00  2.016359e+00  9.990271e-01  1.370703e+00
#
#          Z53_normal  LatMom_normal
# count  4.336000e+04   4.336000e+04
# mean  -1.245416e-17  -3.755913e-16
# std    1.000000e+00   1.000000e+00
# min   -6.962164e-01  -1.978281e+00
# 25%   -3.785775e-01  -7.978662e-01
# 50%   -1.760930e-01  -4.048754e-01
# 75%    1.099521e-01   8.926561e-01
# max    8.214382e+01   2.102946e+00
